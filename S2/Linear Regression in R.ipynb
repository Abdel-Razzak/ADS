# %% [markdown]
# # Linear Regression ¶
# Make sure you've read the introduction [notes on Linear Regression]() and [read Chapters 2 and 3 of ISLR]() before continuing!
#
# Remember that Linear Regression is a supervised learning algorithm, meaning we'll have labeled data and try to predict new labels on unlabeled data. We'll explore some of the following concepts:
# * Get our Data
# * Exploratory Data Analysis (EDA)
# * Clean our Data
# * Review of Model Form
# * Train and Test Groups
# * Linear Regression Model

# %% [markdown]
# ## Get our Data
# We will use the Student Performance Data Set from CELT database at An-Najah National University use the supplied csv files in the notebook repository. We'll specifically look at the math class (student-mat.csv). Make sure to take note that the delimiter is a semi-colon.

# %%
# Read CSV, note the delimiter (sep)
df <- read.csv('student/student-mat.csv',sep=';')

# %%
head(df)
# Out:
#   school sex age address famsize Pstatus Medu Fedu Mjob     Fjob     ... famrel
# 1 GP     F   18  U       GT3     A       4    4    at_home  teacher  ... 4
# 2 GP     F   17  U       GT3     T       1    1    at_home  other    ... 5
# 3 GP     F   15  U       LE3     T       1    1    at_home  other    ... 4
# 4 GP     F   15  U       GT3     T       4    2    health   services ... 3
# 5 GP     F   16  U       GT3     T       3    3    other    other    ... 4
# 6 GP     M   16  U       LE3     T       4    3    services other    ... 5
#   freetime goout Dalc Walc health absences G1 G2 G3
# 1 3        4     1    1    3       6        5  6  6
# 2 3        3     1    1    3       4        5  5  6
# 3 3        2     2    3    3      10        7  8 10
# 4 2        2     1    1    5       2       15 14 15
# 5 3        2     1    2    5       4        6 10 10
# 6 4        2     1    2    5      10       15 15 15

# %%
df <- df[ , -c(12, 23, 27, 28)]

# %%
head(df)
# Out:
#   school sex age address famsize Pstatus Medu Fedu Mjob     Fjob     ... higher
# 1 GP     F   18  U       GT3     A       4    4    at_home  teacher  ... yes
# 2 GP     F   17  U       GT3     T       1    1    at_home  other    ... yes
# 3 GP     F   15  U       LE3     T       1    1    at_home  other    ... yes
# 4 GP     F   15  U       GT3     T       4    2    health   services ... yes
# 5 GP     F   16  U       GT3     T       3    3    other    other    ... yes
# 6 GP     M   16  U       LE3     T       4    3    services other    ... yes
#   internet famrel freetime goout health absences G1 G2 G3
# 1 no       4      3        4     3       6        5  6  6
# 2 yes      5      3        3     3       4        5  5  6
# 3 yes      4      3        2     3      10        7  8 10
# 4 yes      3      2        2     5       2       15 14 15
# 5 no       4      3        2     5       4        6 10 10
# 6 yes      5      4        2     5      10       15 15 15

# %%
df$school <- as.character(df$school)
df$school[df$school == "GP"] <- "R"
df$school[df$school == "MS"] <- "R1"
df$age <-as.numeric(df$age)
df$age[df$age < 18] <- 19
# Out:
#   [1] 18 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19
#  [26] 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19
#  [51] 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19
#  [76] 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19
# [101] 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19
# [126] 19 19 19 18 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19
# [151] 18 19 19 19 19 19 19 18 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19
# [176] 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19 19
# [201] 19 19 19 19 19 19 19 19 19 19 19 19 19 18 19 19 19 18 19 19 19 19 19 18 19
# [226] 18 19 19 18 19 19 19 19 19 19 19 19 19 19 18 19 19 19 19 18 19 19 22 18 19
# [251] 18 19 18 19 19 19 19 19 18 19 18 18 18 19 18 18 19 18 18 18 19 18 18 19 19
# [276] 19 18 18 18 18 19 19 18 18 19 19 18 19 18 18 18 19 18 19 18 19 19 18 18 18
# ...

# %%
df$school <- as.factor(df$school)
df$school
# Out:
#   [1] R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R
#  [26] R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R
#  [51] R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R
#  [76] R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R
# [101] R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R
# [126] R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R
# [151] R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R
# [176] R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R
# [201] R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R
# [226] R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R
# [251] R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R
# [276] R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R  R
# ...
